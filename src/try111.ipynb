# %%
# !/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on 20180517

@author: zhangji
"""

# %pylab notebook
pylab.rcParams['figure.figsize'] = (18.5, 10.5)

import numpy as np
import pandas as pd
import os
import glob
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
from IPython.display import display, HTML
from geo import *

PWD = os.getcwd()
fontsize = 40
np.set_printoptions(linewidth=110, precision=5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
thlx_geo = infHelix(maxlength=26 * np.pi, nSegment=300)
# create_n(self, R, rho, ph, n, theta0=0)
thlx_geo.create_n(R=1, rho=0.2, ph=5, n=100, theta0=0)
helix_nodes = []

fig = plt.figure(figsize=(8, 5))
ax1 = fig.add_subplot(111, projection='3d')
fig.patch.set_facecolor('white')
for percentage in np.linspace(0, 1, thlx_geo.get_nSegment()):
    helix_nodes.append(thlx_geo.coord_x123(percentage))
    ax1.plot(*thlx_geo.coord_x123(percentage).T)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
helix_nodes
# Out:
# [array([[  1.00000e+00,  -1.24535e-01,   1.56496e-01],
#         [  9.87442e-01,  -1.24290e-01,   1.56187e-01],
#         [  9.74933e-01,  -1.23553e-01,   1.55262e-01],
#         [  9.62524e-01,  -1.22330e-01,   1.53724e-01],
#         [  9.50262e-01,  -1.20623e-01,   1.51579e-01],
#         [  9.38197e-01,  -1.18440e-01,   1.48836e-01],
#         [  9.26375e-01,  -1.15790e-01,   1.45506e-01],
#         [  9.14844e-01,  -1.12683e-01,   1.41602e-01],
#         [  9.03649e-01,  -1.09131e-01,   1.37138e-01],
#         [  8.92835e-01,  -1.05149e-01,   1.32134e-01],
#         [  8.82443e-01,  -1.00751e-01,   1.26608e-01],
#         [  8.72515e-01,  -9.59562e-02,   1.20582e-01],
#         [  8.63091e-01,  -9.07824e-02,   1.14081e-01],
#         [  8.54206e-01,  -8.52503e-02,   1.07129e-01],
#         [  8.45897e-01,  -7.93819e-02,   9.97542e-02],
#         [  8.38197e-01,  -7.32001e-02,   9.19859e-02],
#         [  8.31134e-01,  -6.67294e-02,   8.38546e-02],
# ...
