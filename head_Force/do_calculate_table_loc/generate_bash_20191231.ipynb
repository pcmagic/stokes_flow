# %%
import numpy as np
import os
from codeStore import support_fun as spf
import importlib
PWD = os.getcwd()

# %%
importlib.reload(spf)
ini_psi_type = 'rand'
use_node = 3
ncpu_node = 24
def comm_do_calculate(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                      calculate_fun, update_fun, table_name, omega_tail):
    ts = 'python ../../do_calculate.py  '
    ts = ts + ' -ini_theta %f -ini_phi %f -ini_psi %f' % (ini_theta, ini_phi, ini_psi)
    ts = ts + ' -max_t %f -rtol %e -atol %e -eval_dt %e' % (max_t, rtol, atol, eval_dt)
    ts = ts + ' -calculate_fun %s -update_fun %s -table_name %s' % (calculate_fun, update_fun, table_name)
    ts = ts + ' -omega_tail %f' % omega_tail
    return ts

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao0_wm1'
# job_dir = 'ecoC01B05_bulk_psi-0a'
# omega_tail = 1
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0'
# job_dir = 'ecoC01B05_passive_psi-0a'
# omega_tail = 0
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.01'
# job_dir = 'ecoC01B05_wt0.01_psi-0a'
# omega_tail = 0.01
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.1'
# job_dir = 'ecoC01B05_wt0.1_psi-0a'
# omega_tail = 0.1
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.2'
# job_dir = 'ecoC01B05_wt0.2_psi-0a'
# omega_tail = 0.2
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.3'
# job_dir = 'ecoC01B05_wt0.3_psi-0a'
# omega_tail = 0.3
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.4'
# job_dir = 'ecoC01B05_wt0.4_psi-0a'
# omega_tail = 0.4
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.5'
# job_dir = 'ecoC01B05_wt0.5_psi-0a'
# omega_tail = 0.5
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.6'
# job_dir = 'ecoC01B05_wt0.6_psi-0a'
# omega_tail = 0.6
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.7'
# job_dir = 'ecoC01B05_wt0.7_psi-0a'
# omega_tail = 0.7
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.8'
# job_dir = 'ecoC01B05_wt0.8_psi-0a'
# omega_tail = 0.8
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.9'
# job_dir = 'ecoC01B05_wt0.9_psi-0a'
# omega_tail = 0.9
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm1'
# job_dir = 'ecoC01B05_wt1_psi-0a'
# omega_tail = 1
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 5000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm10'
# job_dir = 'ecoC01B05_wt10_psi-0a'
# omega_tail = 10
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 1000, 1e-6, 1e-9, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm100'
# job_dir = 'ecoC01B05_wt100_psi-0a'
# omega_tail = 100
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-12, 1e-15, 1e-3, '5bs'
# calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
# table_name = 'ecoC01B05_tao1_wm0.5'
# job_dir = 'ecoC01B05_wt0.5_psi-0b'
# omega_tail = 0.5
# n_theta, n_phi = 23, 45 # num of cpus and num of jobs
# write_pbs_head = spf.write_pbs_head
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)

########################################################################################################
t_path = os.path.join(PWD, job_dir)
if not os.path.exists(t_path):
    os.makedirs(t_path)
# generate all comment file. 
theta_list, phi_list = np.meshgrid(theta_list, phi_list)
comm_list = []
t_name0 = os.path.join(t_path, 'comm_list.sh')
with open(t_name0, 'w') as fcomm:
    for i0, (ini_theta, ini_phi) in enumerate(zip(theta_list.ravel(), phi_list.ravel())):
        ini_psi = np.random.sample(1) if ini_psi_type is 'rand' else ini_psi_type
        ts = comm_do_calculate(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                               calculate_fun, update_fun, table_name, omega_tail)
        comm_list.append(ts)
        fcomm.write(ts)
        fcomm.write('\n\n')
n_case = len(comm_list)
# generate .pbs file and .csh file
n_pbs = 0
n_job_pbs = use_node * ncpu_node
t_name0 = os.path.join(t_path, 'main_run.sh')
with open(t_name0, 'w') as frun:
    frun.write('t_dir=$PWD \n\n')
    for t1 in np.arange((n_case // n_job_pbs) + 1): 
        use_comm = comm_list[t1*n_job_pbs : np.min(((t1+1)*n_job_pbs, n_case))]
        n_use_comm = len(use_comm)
        tnode = np.ceil(n_use_comm / ncpu_node)
        pbs_name = 'run%03d.pbs' % t1
        csh_name = 'run%03d.csh' % t1
        # generate .pbs file
        t_name = os.path.join(t_path, pbs_name)
        with open(t_name, 'w') as fpbs:
            pbs_head = '%s_%s' % (job_dir, pbs_name)
            write_pbs_head(fpbs, pbs_head, nodes=tnode) 
            t2 = 'seq 0 %d | parallel -j %d -u ' % (n_use_comm-1, ncpu_node)
            t2 = t2 + ' --sshloginfile $PBS_NODEFILE --sshdelay 0.1 '
            t2 = t2 + '"cd $PWD; echo $PWD; bash %s {} true " \n\n ' % csh_name
            fpbs.write(t2)
        # generate .csh file for submit
        t_name = os.path.join(t_path, csh_name)
        with open(t_name, 'w') as fcsh:
            fcsh.write('#!/bin/csh -fe \n\n')
            t2 = 'comm_list=('
            for t3 in use_comm:
                t2 = t2 + '"%s" ' % t3
            t2 = t2 + ') \n\n'
            fcsh.write(t2)
            fcsh.write('echo ${comm_list[$1]} \n')
            fcsh.write('if [ ${2:-false} = true ]; then \n')
            fcsh.write('    ${comm_list[$1]} \n')
            fcsh.write('fi \n\n')
        frun.write('qsub %s\n\n' % pbs_name)
        n_pbs = n_pbs + 1
    frun.write('\n')
print(t_path)
print('n_pbs = ', n_pbs)
# Out:
# /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt0.7_psi-0b
# n_pbs =  15

# %%
1781 / (1781 + 1560 + 86)
# Out:
# 0.5196965275751386

# %%
importlib.reload(spf)
ini_psi_type = 'rand'
use_node = 3
njob_node = 24
n_job_pbs = use_node * njob_node
random_order = True

def comm_do_calculate(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                      calculate_fun, update_fun, table_name, omega_tail):
    ts = 'python ../../do_calculate.py  '
    ts = ts + ' -ini_theta %f -ini_phi %f -ini_psi %f' % (ini_theta, ini_phi, ini_psi)
    ts = ts + ' -max_t %f -rtol %e -atol %e -eval_dt %e' % (max_t, rtol, atol, eval_dt)
    ts = ts + ' -calculate_fun %s -update_fun %s -table_name %s' % (calculate_fun, update_fun, table_name)
    ts = ts + ' -omega_tail %f' % omega_tail
    return ts

max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-12, 1e-15, 1e-3, '5bs'
calculate_fun = 'do_calculate_ecoli_Petsc4nPsi'
table_name = 'ecoC01B05_tao1_wm0.7'
job_dir = 'ecoC01B05_wt0.7_psi-0c'
omega_tail = 0.7
n_theta, n_phi = 23, 45 # num of cpus and num of jobs
write_pbs_head = spf.write_pbs_head
ini_psi_type = 0
phi_list = np.linspace(0, 2 * np.pi, n_phi)
theta_list = np.linspace(0, np.pi, n_theta)
use_node = 15
n_job_pbs = 10000

########################################################################################################
t_path = os.path.join(PWD, job_dir)
if not os.path.exists(t_path):
    os.makedirs(t_path)
# generate all comment file. 
theta_list, phi_list = np.meshgrid(theta_list, phi_list)
comm_list = []
txt_list = []
for i0, (ini_theta, ini_phi) in enumerate(zip(theta_list.ravel(), phi_list.ravel())):
    ini_psi = np.random.sample(1) if ini_psi_type is 'rand' else ini_psi_type
    f = 'th%5.3f_ph%5.3f_ps%5.3f' % (ini_theta, ini_phi, ini_psi)
    ts = comm_do_calculate(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                           calculate_fun, update_fun, table_name, omega_tail)
    comm_list.append(ts)
    txt_list.append(f)
spf.write_main_run_comm_list(comm_list, txt_list, use_node, njob_node, job_dir, 
                             write_pbs_head, n_job_pbs, random_order=random_order)
# Out:
# exist folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt0.7_psi-0c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 0.713998 -ini_phi 5.854786 -ini_psi 0.000000 -max_t 10000.000000 -rtol 1.000000e-12 -atol 1.000000e-15 -eval_dt 1.000000e-03 -calculate_fun do_calculate_ecoli_Petsc4nPsi -update_fun 5bs -table_name ecoC01B05_tao1_wm0.7 -omega_tail 0.700000
# True

# %% [markdown]
# ## new theory version

# %%
importlib.reload(spf)
use_node = 3
njob_node = 24
n_job_pbs = use_node * njob_node
random_order = True
ini_t = 0

def comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                   update_fun, table_name, omega_tail, flow_strength=1, ini_t=0, ):
    calculate_fun = 'do_ShearFlowPetsc4nPsiObj'
    ts = 'python ../../do_calculate.py  '
    ts = ts + ' -ini_theta %f -ini_phi %f -ini_psi %f' % (ini_theta, ini_phi, ini_psi)
    ts = ts + ' -max_t %f -rtol %e -atol %e -eval_dt %e' % (max_t, rtol, atol, eval_dt)
    ts = ts + ' -calculate_fun %s -update_fun %s -table_name %s' % (calculate_fun, update_fun, table_name)
    ts = ts + ' -omega_tail %f -flow_strength %f -ini_t %f' % (omega_tail, flow_strength, ini_t)
    return ts

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_passive_psi_rada'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head_q03
# n_rand_case = 10000
# use_node = 10
# n_job_pbs = 10000000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.1_psi_rada'
# omega_tail, flow_strength = 0.1, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 10
# n_job_pbs = 10000000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.3_psi_rada'
# omega_tail, flow_strength = 0.3, 1
# write_pbs_head = spf.write_pbs_head_q03
# n_rand_case = 10000
# use_node = 10
# n_job_pbs = 10000000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.5_psi_rada'
# omega_tail, flow_strength = 0.5, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 3
# n_job_pbs = 10000000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.7_psi_rada'
# omega_tail, flow_strength = 0.7, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 3
# n_job_pbs = 10000000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.9_psi_rada'
# omega_tail, flow_strength = 0.9, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 3
# n_job_pbs = 10000000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_passive_psi_radb'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head_newturb
# n_rand_case = 10000
# use_node = 1
# n_job_pbs = 1000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.1_psi_radb'
# omega_tail, flow_strength = 0.1, 1
# write_pbs_head = spf.write_pbs_head_newturb
# n_rand_case = 10000
# use_node = 1
# n_job_pbs = 1000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.3_psi_radb'
# omega_tail, flow_strength = 0.3, 1
# write_pbs_head = spf.write_pbs_head_newturb
# n_rand_case = 10000
# use_node = 1
# n_job_pbs = 1000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.5_psi_radb'
# omega_tail, flow_strength = 0.5, 1
# write_pbs_head = spf.write_pbs_head_newturb
# n_rand_case = 10000
# use_node = 1
# n_job_pbs = 1000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.7_psi_radb'
# omega_tail, flow_strength = 0.7, 1
# write_pbs_head = spf.write_pbs_head_newturb
# n_rand_case = 10000
# use_node = 1
# n_job_pbs = 1000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.9_psi_radb'
# omega_tail, flow_strength = 0.9, 1
# write_pbs_head = spf.write_pbs_head_newturb
# n_rand_case = 10000
# use_node = 1
# n_job_pbs = 1000

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.6_psi_rada'
# omega_tail, flow_strength = 0.6, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.55_psi_rada'
# omega_tail, flow_strength = 0.55, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.65_psi_rada'
# omega_tail, flow_strength = 0.65, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.06_psi_rada'
# omega_tail, flow_strength = 0.06, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.015_psi_rada'
# omega_tail, flow_strength = 0.015, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 10
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.02_psi_rada'
# omega_tail, flow_strength = 0.02, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 10
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.55_psi_radb'
# omega_tail, flow_strength = 0.55, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.6_psi_radb'
# omega_tail, flow_strength = 0.6, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 10
# use_node = 1
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt0.06_psi_rada'
# omega_tail, flow_strength = 0.06, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt1_psi_rada'
# omega_tail, flow_strength = 1, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_wt2_psi_rada'
# omega_tail, flow_strength = 2, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_left_baseFlow'
# job_dir = 'ecoC01B05_left_wt0_psi_rada'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 10
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_left_baseFlow'
# job_dir = 'ecoC01B05_left_wt0.7_psi_rada'
# omega_tail, flow_strength = 0.7, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_left_baseFlow'
# job_dir = 'ecoC01B05_left_wt2_psi_rada'
# omega_tail, flow_strength = 2, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 10
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_left_baseFlow'
# job_dir = 'ecoC01B05_left_wt-0.7_psi_rada'
# omega_tail, flow_strength = -0.7, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_left_baseFlow'
# job_dir = 'ecoC01B05_left_wt-2_psi_rada'
# omega_tail, flow_strength = -2, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 10
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'hlxB01_baseFlow'
# job_dir = 'hlxB01_baseFlow_psi_rada'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'hlxB03_baseFlow'
# job_dir = 'hlxB03_baseFlow_psi_rada'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'hlxC01_baseFlow'
# job_dir = 'hlxC01_baseFlow_psi_rada'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 7
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0_psi_rada'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 20
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w1_psi_rada'
# omega_tail, flow_strength = 1, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 11000
# use_node = 15
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.01_psi_rada'
# omega_tail, flow_strength = 0.01, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.015_psi_rada'
# omega_tail, flow_strength = 0.015, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.02_psi_rada'
# omega_tail, flow_strength = 0.02, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.1_psi_rada'
# omega_tail, flow_strength = 0.1, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.2_psi_rada'
# omega_tail, flow_strength = 0.2, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.3_psi_rada'
# omega_tail, flow_strength = 0.3, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.4_psi_rada'
# omega_tail, flow_strength = 0.4, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.5_psi_rada'
# omega_tail, flow_strength = 0.5, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.6_psi_rada'
# omega_tail, flow_strength = 0.6, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w0.7_psi_rada'
# omega_tail, flow_strength = 0.7, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoB01B05_baseFlow'
# job_dir = 'ecoB01B05_w2_psi_rada'
# omega_tail, flow_strength = 2, 1
# write_pbs_head = spf.write_pbs_head
# n_rand_case = 1100
# use_node = 3
# n_job_pbs = n_rand_case

########################################################################################################
t_path = os.path.join(PWD, job_dir)
if not os.path.exists(t_path):
    os.makedirs(t_path)
# generate all comment file. 
comm_list = []
txt_list = []
for i0 in range(n_rand_case):
    ini_theta, ini_phi, ini_psi = np.random.sample(3) * np.pi * (1, 2, 2)
    f = 'th%07.5f_ph%07.5f_ps%07.5f' % (ini_theta, ini_phi, ini_psi)
    ts = comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                        update_fun, table_name, omega_tail, flow_strength, ini_t)
    comm_list.append(ts)
    txt_list.append(f)
spf.write_main_run_comm_list(comm_list, txt_list, use_node, njob_node, job_dir, 
                             write_pbs_head, n_job_pbs, random_order=random_order)
# Out:
# exist folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoB01B05_w2_psi_rada
# input 1100 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 2.920630 -ini_phi 1.762378 -ini_psi 0.447326 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoB01B05_baseFlow -omega_tail 2.000000 -flow_strength 1.000000 -ini_t 0.000000
# True

# %%
importlib.reload(spf)
use_node = 3
njob_node = 24
n_job_pbs = use_node * njob_node
random_order = True
ini_t = 0

def comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                   update_fun, table_name, omega_tail, flow_strength=1, ini_t=0, ):
    calculate_fun = 'do_ShearFlowPetsc4nPsiObj'
    ts = 'python ../../do_calculate.py  '
    ts = ts + ' -ini_theta %f -ini_phi %f -ini_psi %f' % (ini_theta, ini_phi, ini_psi)
    ts = ts + ' -max_t %f -rtol %e -atol %e -eval_dt %e' % (max_t, rtol, atol, eval_dt)
    ts = ts + ' -calculate_fun %s -update_fun %s -table_name %s' % (calculate_fun, update_fun, table_name)
    ts = ts + ' -omega_tail %f -flow_strength %f -ini_t %f' % (omega_tail, flow_strength, ini_t)
    return ts

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir = 'ecoC01B05_passive_psi-0b'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head
# n_theta, n_phi = 23, 45
# ini_psi_type = 0
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)
# use_node = 5
# n_job_pbs = n_rand_case

########################################################################################################
t_path = os.path.join(PWD, job_dir)
if not os.path.exists(t_path):
    os.makedirs(t_path)
# generate all comment file. 
comm_list = []
txt_list = []
theta_list, phi_list = np.meshgrid(theta_list, phi_list)
for ini_theta, ini_phi in zip(theta_list.ravel(), phi_list.ravel()):
    ini_psi = np.random.sample(1) if ini_psi_type is 'rand' else ini_psi_type
    f = 'th%07.5f_ph%07.5f_ps%07.5f' % (ini_theta, ini_phi, ini_psi)
    ts = comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                        update_fun, table_name, omega_tail, flow_strength, ini_t)
    comm_list.append(ts)
    txt_list.append(f)
spf.write_main_run_comm_list(comm_list, txt_list, use_node, njob_node, job_dir, 
                             write_pbs_head, n_job_pbs, random_order=random_order)
# Out:
# exist folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_passive_psi-0b
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 0.428399 -ini_phi 4.569589 -ini_psi 0.000000 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 0.000000 -flow_strength 1.000000 -ini_t 0.000000
# True

# %%
importlib.reload(spf)
use_node = 3
njob_node = 24
n_job_pbs = use_node * njob_node
random_order = True
ini_t = 0

def comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                   update_fun, table_name, omega_tail, flow_strength=1, ini_t=0, ):
    calculate_fun = 'do_ShearFlowPetsc4nPsiObj'
    ts = 'python ../../do_calculate.py  '
    ts = ts + ' -ini_theta %f -ini_phi %f -ini_psi %f' % (ini_theta, ini_phi, ini_psi)
    ts = ts + ' -max_t %f -rtol %e -atol %e -eval_dt %e' % (max_t, rtol, atol, eval_dt)
    ts = ts + ' -calculate_fun %s -update_fun %s -table_name %s' % (calculate_fun, update_fun, table_name)
    ts = ts + ' -omega_tail %f -flow_strength %f -ini_t %f' % (omega_tail, flow_strength, ini_t)
    return ts

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir_handle = 'ecoC01B05_passive_psi-%.3fc'
# omega_tail, flow_strength = 0, 1
# write_pbs_head = spf.write_pbs_head
# n_theta, n_phi = 23, 45
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)
# psi_list = np.linspace(0, 2, 8, endpoint=False) * np.pi
# use_node = 5
# n_job_pbs = n_rand_case

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# job_dir_handle = 'ecoC01B05_wt0.1_psi-%.3fc'
# omega_tail, flow_strength = 0.1, 1
# write_pbs_head = spf.write_pbs_head
# n_theta, n_phi = 23, 45
# phi_list = np.linspace(0, 2 * np.pi, n_phi)
# theta_list = np.linspace(0, np.pi, n_theta)
# psi_list = np.linspace(0, 2, 8, endpoint=False) * np.pi
# use_node = 5
# n_job_pbs = n_rand_case

max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
table_name = 'ecoC01B05_baseFlow'
job_dir_handle = 'ecoC01B05_wt1_psi-%.3fc'
omega_tail, flow_strength = 1, 1
write_pbs_head = spf.write_pbs_head
n_theta, n_phi = 23, 45
phi_list = np.linspace(0, 2 * np.pi, n_phi)
theta_list = np.linspace(0, np.pi, n_theta)
psi_list = np.linspace(0, 2, 8, endpoint=False) * np.pi
use_node = 5
n_job_pbs = n_rand_case

########################################################################################################
theta_list, phi_list = np.meshgrid(theta_list, phi_list)
for ini_psi_type in psi_list:
    job_dir = job_dir_handle % ini_psi_type
#     print(ini_psi_type / np.pi, job_dir)
    t_path = os.path.join(PWD, job_dir)
    # generate all comment file. 
    comm_list = []
    txt_list = []
    for ini_theta, ini_phi in zip(theta_list.ravel(), phi_list.ravel()):
        ini_psi = np.random.sample(1) if ini_psi_type is 'rand' else ini_psi_type
        f = 'th%07.5f_ph%07.5f_ps%07.5f' % (ini_theta, ini_phi, ini_psi)
        ts = comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                            update_fun, table_name, omega_tail, flow_strength, ini_t)
        comm_list.append(ts)
        txt_list.append(f)
    spf.write_main_run_comm_list(comm_list, txt_list, use_node, njob_node, job_dir, 
                                 write_pbs_head, n_job_pbs, random_order=random_order)
# Out:
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-0.000c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 0.999598 -ini_phi 4.426790 -ini_psi 0.000000 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-0.785c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 2.855993 -ini_phi 5.711987 -ini_psi 0.785398 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-1.571c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 0.142800 -ini_phi 5.426387 -ini_psi 1.570796 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-2.356c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 1.285197 -ini_phi 0.000000 -ini_psi 2.356194 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-3.142c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 2.284795 -ini_phi 4.569589 -ini_psi 3.141593 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-3.927c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 2.427594 -ini_phi 0.428399 -ini_psi 3.926991 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-4.712c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 1.999195 -ini_phi 5.283588 -ini_psi 4.712389 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_wt1_psi-5.498c
# input 1035 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 2.570394 -ini_phi 4.283990 -ini_psi 5.497787 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 1.000000 -flow_strength 1.000000 -ini_t 0.000000

# %%
importlib.reload(spf)
use_node = 3
njob_node = 24
n_job_pbs = use_node * njob_node
random_order = True
ini_t = 0

def comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                   update_fun, table_name, omega_tail, flow_strength, ini_t, f):
    calculate_fun = 'do_ShearFlowPetsc4nPsiObj'
    ts = 'python ../../do_calculate.py  '
    ts = ts + ' -ini_theta %f -ini_phi %f -ini_psi %f' % (ini_theta, ini_phi, ini_psi)
    ts = ts + ' -max_t %f -rtol %e -atol %e -eval_dt %e' % (max_t, rtol, atol, eval_dt)
    ts = ts + ' -calculate_fun %s -update_fun %s -table_name %s' % (calculate_fun, update_fun, table_name)
    ts = ts + ' -omega_tail %f -flow_strength %f -ini_t %f' % (omega_tail, flow_strength, ini_t)
    ts = ts + ' -f %s' % f    
    return ts

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# flow_strength = 1
# write_pbs_head = spf.write_pbs_head
# ini_theta, ini_phi, ini_psi = 1.285, 2.999, 0.000
# job_dir = 'ecoC01B05_th%.3f_ph%.3f_ps%.3f' % (ini_theta, ini_phi, ini_psi)
# omega_tail_list = np.hstack((0, 10 ** np.linspace(-3, 1, 110)))
# use_node = 5
# n_job_pbs = n_rand_case

########################################################################################################
t_path = os.path.join(PWD, job_dir)
if not os.path.exists(t_path):
    os.makedirs(t_path)
# generate all comment file. 
comm_list = []
txt_list = []
for omega_tail in omega_tail_list:
    f = 'omega_tail%08.5f' % omega_tail
    ts = comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                        update_fun, table_name, omega_tail, flow_strength, ini_t, f)
    comm_list.append(ts)
    txt_list.append(f)
spf.write_main_run_comm_list(comm_list, txt_list, use_node, njob_node, job_dir, 
                             write_pbs_head, n_job_pbs, random_order=random_order)
# Out:
# exist folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_th1.285_ph2.999_ps0.000
# input 111 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../do_calculate.py   -ini_theta 1.285000 -ini_phi 2.999000 -ini_psi 0.000000 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow -omega_tail 0.003865 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail00.00387
# True

# %%
from matplotlib import pyplot as plt

importlib.reload(spf)
use_node = 3
njob_node = 24
n_job_pbs = use_node * njob_node
random_order = True
ini_t = 0
rand_w_fct = 0

def comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                   update_fun, table_name, omega_tail, flow_strength, ini_t, f):
    calculate_fun = 'do_ShearFlowPetsc4nPsiObj'
    ts = 'python ../../../do_calculate.py  '
    ts = ts + ' -ini_theta %f -ini_phi %f -ini_psi %f' % (ini_theta, ini_phi, ini_psi)
    ts = ts + ' -max_t %f -rtol %e -atol %e -eval_dt %e' % (max_t, rtol, atol, eval_dt)
    ts = ts + ' -calculate_fun %s -update_fun %s -table_name %s' % (calculate_fun, update_fun, table_name)
    ts = ts + ' -omega_tail %f -flow_strength %f -ini_t %f' % (omega_tail, flow_strength, ini_t)
    ts = ts + ' -f %s' % f    
    return ts

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# flow_strength = 1
# omega_tail_list = np.hstack((0, 10 ** np.linspace(-3, 1, 50)))
# use_node = 1
# n_ini = 90
# n_job_pbs = n_ini
# write_pbs_head = spf.write_pbs_head
# job_dir_handle = 'ecoC01B05_inithphps_a'
# write_pbs_head = spf.write_pbs_head_dbg
# job_dir_handle = 'ecoC01B05_inithphps_b'
# write_pbs_head = spf.write_pbs_head_newturb
# job_dir_handle = 'ecoC01B05_inithphps_c'
# write_pbs_head = spf.write_pbs_head_serial
# job_dir_handle = 'ecoC01B05_inithphps_d'

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# flow_strength = 1
# omega_tail_list = np.hstack((0, 10 ** np.linspace(-3, 1, 50)[:-1], 10 ** np.linspace(1, 2, 10)))
# use_node = 1
# n_ini = 100
# n_job_pbs = 1000000
# write_pbs_head = spf.write_pbs_head
# job_dir_handle = 'ecoC01B05_inithphps_f'

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# flow_strength = 1
# omega_tail_list = np.hstack((0, 10 ** np.linspace(-3, 1, 50)[:-1]))
# rand_w_fct = 0.1
# use_node = 1
# n_ini = 90
# n_job_pbs = 1000000
# write_pbs_head = spf.write_pbs_head
# job_dir_handle = 'ecoC01B05_inithphps_g'
# write_pbs_head = spf.write_pbs_head
# job_dir_handle = 'ecoC01B05_inithphps_h'

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# flow_strength = 1
# omega_tail_list = np.hstack((0, 10 ** np.linspace(-3, 1, 50)[:-1]))
# rand_w_fct = 0.01
# use_node = 1
# n_ini = 90
# n_job_pbs = 1000000
# write_pbs_head = spf.write_pbs_head
# job_dir_handle = 'ecoC01B05_inithphps_i'
# write_pbs_head = spf.write_pbs_head
# job_dir_handle = 'ecoC01B05_inithphps_j'

# max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
# table_name = 'ecoC01B05_baseFlow'
# flow_strength = 1
# omega_tail_list = np.linspace(2.5, 4.5, 50)
# rand_w_fct = 0.1
# use_node = 1
# n_ini = 100
# n_job_pbs = 1000000
# # write_pbs_head = spf.write_pbs_head_newturb
# # job_dir_handle = 'ecoC01B05_inithphps_k'
# # write_pbs_head = spf.write_pbs_head_newturb
# # job_dir_handle = 'ecoC01B05_inithphps_l'
# write_pbs_head = spf.write_pbs_head_newturb
# job_dir_handle = 'ecoC01B05_inithphps_m'

max_t, rtol, atol, eval_dt, update_fun = 10000, 1e-9, 1e-12, 1e-3, '5bs'
table_name = 'ecoC01B05_baseFlow_refine'
flow_strength = 1
omega_tail_list = np.linspace(2.5, 4.5, 50)
rand_w_fct = 0.1
use_node = 1
n_ini = 100
n_job_pbs = 1000000
write_pbs_head = spf.write_pbs_head
job_dir_handle = 'ecoC01B05_inithphps_n'
# write_pbs_head = spf.write_pbs_head_newturb
# job_dir_handle = 'ecoC01B05_inithphps_o'
# write_pbs_head = spf.write_pbs_head_newturb
# job_dir_handle = 'ecoC01B05_inithphps_p'

########################################################################################################
# generate all comment file. 
sub_dir_list = []
w_all = []
for i0 in range(n_ini):
    comm_list = []
    txt_list = []
    ini_theta, ini_phi, ini_psi = np.random.sample(3) * np.pi * (1, 2, 2)
    sub_job_dir = 'th%.5f_ph%.5f_ps%.5f' % (ini_theta, ini_phi, ini_psi)
    sub_dir_list.append(sub_job_dir)
    job_dir = os.path.join(job_dir_handle, sub_job_dir)
    wi = []
    for omega_tail0 in omega_tail_list:
        omega_tail = omega_tail0 + (np.random.sample(1) * 2 - 1) * omega_tail0 * rand_w_fct
        wi.append(omega_tail)
        f = 'omega_tail%08.5f' % omega_tail
        ts = comm_do_ShearFlowPetsc4nPsiObj(ini_theta, ini_phi, ini_psi, max_t, rtol, atol, eval_dt, 
                                            update_fun, table_name, omega_tail, flow_strength, ini_t, f)
        comm_list.append(ts)
        txt_list.append(f)
    w_all.append(wi)
    spf.write_main_run_comm_list(comm_list, txt_list, use_node, njob_node, job_dir, 
                                 write_pbs_head, n_job_pbs, random_order=random_order)
t_name0 = os.path.join(job_dir_handle, 'main_run.sh')
with open(t_name0, 'w') as frun:
    frun.write('tdir=$PWD \n\n')
    for sub_job_dir in sub_dir_list:
        frun.write('sub_dir=$tdir/%s \n' % sub_job_dir)
        frun.write('cd $sub_dir \n')
        frun.write('echo $PWD \n')
        frun.write('bash main_run.sh \n\n')
    frun.write('cd $tdir \n')
        
figsize = np.array((16, 9)) * 0.5
dpi = 100
fig, axi = plt.subplots(1, 1, figsize=figsize, dpi=dpi)
fig.patch.set_facecolor('white')
for wi in w_all:
    axi.plot(wi, '.')
# Out:
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th3.02621_ph4.35431_ps4.03641
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 3.026206 -ini_phi 4.354307 -ini_psi 4.036407 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.607550 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.60755
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.40445_ph5.17516_ps4.54686
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.404446 -ini_phi 5.175164 -ini_psi 4.546862 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.838594 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.83859
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.68159_ph2.65994_ps0.23696
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.681588 -ini_phi 2.659937 -ini_psi 0.236959 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.335176 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.33518
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.70142_ph1.80118_ps4.97008
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.701417 -ini_phi 1.801182 -ini_psi 4.970078 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.221471 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.22147
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th3.04710_ph0.49272_ps3.73901
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 3.047098 -ini_phi 0.492721 -ini_psi 3.739011 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.876012 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.87601
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.49539_ph5.96552_ps4.27607
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.495388 -ini_phi 5.965523 -ini_psi 4.276071 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.250598 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.25060
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.53390_ph3.09178_ps5.19177
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.533899 -ini_phi 3.091777 -ini_psi 5.191767 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.962695 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.96269
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.21159_ph5.59039_ps1.90056
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.211593 -ini_phi 5.590394 -ini_psi 1.900560 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.169425 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.16942
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.34931_ph1.96294_ps4.83438
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.349314 -ini_phi 1.962943 -ini_psi 4.834382 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.725528 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.72553
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.97836_ph0.58180_ps0.60533
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.978356 -ini_phi 0.581801 -ini_psi 0.605334 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.707443 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.70744
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.74041_ph4.18707_ps0.15369
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.740406 -ini_phi 4.187072 -ini_psi 0.153689 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.155764 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.15576
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.82694_ph2.64893_ps0.21910
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.826939 -ini_phi 2.648926 -ini_psi 0.219104 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.060946 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.06095
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.40469_ph0.26519_ps3.83373
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.404695 -ini_phi 0.265190 -ini_psi 3.833729 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.667298 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.66730
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.83449_ph5.66310_ps1.32033
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.834493 -ini_phi 5.663101 -ini_psi 1.320334 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.772839 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.77284
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.66116_ph4.30603_ps4.24020
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.661162 -ini_phi 4.306030 -ini_psi 4.240204 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.922814 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.92281
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.11772_ph2.33589_ps5.92401
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.117718 -ini_phi 2.335886 -ini_psi 5.924015 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.052737 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.05274
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.52523_ph5.37189_ps4.64677
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.525234 -ini_phi 5.371892 -ini_psi 4.646772 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.961256 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.96126
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.06967_ph3.89524_ps2.30100
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.069672 -ini_phi 3.895243 -ini_psi 2.300997 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.223873 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.22387
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.45448_ph1.02987_ps1.52966
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.454482 -ini_phi 1.029870 -ini_psi 1.529660 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.205267 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.20527
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.99702_ph1.55538_ps2.38005
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.997019 -ini_phi 1.555379 -ini_psi 2.380049 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.994492 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.99449
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.02836_ph1.77851_ps5.43664
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.028357 -ini_phi 1.778506 -ini_psi 5.436638 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.228991 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.22899
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th3.04839_ph2.74047_ps3.28880
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 3.048391 -ini_phi 2.740469 -ini_psi 3.288804 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.824523 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.82452
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.69236_ph4.78610_ps4.71866
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.692359 -ini_phi 4.786097 -ini_psi 4.718659 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.452443 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.45244
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.33802_ph0.19633_ps1.96641
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.338016 -ini_phi 0.196328 -ini_psi 1.966414 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.149787 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.14979
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.01158_ph5.92078_ps0.74630
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.011582 -ini_phi 5.920777 -ini_psi 0.746301 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.304489 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.30449
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.38786_ph1.10589_ps0.61356
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.387864 -ini_phi 1.105888 -ini_psi 0.613564 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.697016 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.69702
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.21349_ph6.07514_ps1.24654
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.213491 -ini_phi 6.075144 -ini_psi 1.246545 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.794980 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.79498
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.58176_ph0.79774_ps5.53430
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.581765 -ini_phi 0.797736 -ini_psi 5.534300 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.823142 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.82314
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.12746_ph3.57371_ps3.03125
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.127461 -ini_phi 3.573714 -ini_psi 3.031248 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.614108 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.61411
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th3.12631_ph0.02583_ps0.09295
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 3.126311 -ini_phi 0.025826 -ini_psi 0.092950 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.337714 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.33771
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.60572_ph3.15314_ps1.63780
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.605723 -ini_phi 3.153143 -ini_psi 1.637796 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.226407 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.22641
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.33516_ph0.92784_ps5.60760
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.335161 -ini_phi 0.927839 -ini_psi 5.607598 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.659552 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.65955
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.81344_ph2.06499_ps5.35303
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.813444 -ini_phi 2.064989 -ini_psi 5.353027 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.599494 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.59949
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.20267_ph4.09184_ps0.22810
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.202667 -ini_phi 4.091839 -ini_psi 0.228102 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.706267 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.70627
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th3.11627_ph2.31169_ps5.40802
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 3.116271 -ini_phi 2.311689 -ini_psi 5.408022 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.763101 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.76310
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.79557_ph3.80309_ps2.15321
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.795572 -ini_phi 3.803093 -ini_psi 2.153213 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.302278 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.30228
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.31753_ph2.25449_ps4.78563
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.317530 -ini_phi 2.254490 -ini_psi 4.785628 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.444890 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.44489
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.57661_ph2.52065_ps5.58892
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.576608 -ini_phi 2.520649 -ini_psi 5.588916 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.322605 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.32261
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.19280_ph0.08283_ps5.66112
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.192802 -ini_phi 0.082831 -ini_psi 5.661115 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.945635 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.94564
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.89789_ph5.20731_ps6.26978
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.897892 -ini_phi 5.207315 -ini_psi 6.269784 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.746280 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.74628
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.07470_ph4.04167_ps2.98943
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.074698 -ini_phi 4.041670 -ini_psi 2.989428 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.584485 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.58449
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.92504_ph3.06758_ps1.47416
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.925037 -ini_phi 3.067581 -ini_psi 1.474159 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.176924 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.17692
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.45297_ph0.73252_ps4.59203
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.452974 -ini_phi 0.732518 -ini_psi 4.592034 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.510573 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.51057
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.77541_ph0.22849_ps5.53224
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.775411 -ini_phi 0.228488 -ini_psi 5.532236 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.572025 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.57203
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.48988_ph0.83041_ps1.29510
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.489883 -ini_phi 0.830406 -ini_psi 1.295104 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.723378 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.72338
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.64010_ph0.18535_ps0.07711
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.640097 -ini_phi 0.185354 -ini_psi 0.077113 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.378923 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.37892
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.21161_ph6.03268_ps3.98290
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.211608 -ini_phi 6.032679 -ini_psi 3.982899 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.542554 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.54255
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.31300_ph2.34983_ps1.56554
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.313001 -ini_phi 2.349830 -ini_psi 1.565542 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.643314 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.64331
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.52034_ph4.67774_ps0.64845
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.520340 -ini_phi 4.677741 -ini_psi 0.648454 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.309475 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.30948
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.91692_ph2.21873_ps6.27321
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.916919 -ini_phi 2.218734 -ini_psi 6.273209 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.068707 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.06871
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.33624_ph2.07071_ps4.03602
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.336235 -ini_phi 2.070713 -ini_psi 4.036018 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.974506 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.97451
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.94027_ph6.24956_ps3.91936
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.940267 -ini_phi 6.249557 -ini_psi 3.919355 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.468270 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.46827
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.75932_ph4.77126_ps2.55432
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.759318 -ini_phi 4.771257 -ini_psi 2.554323 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.281893 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.28189
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.30407_ph1.79447_ps4.46385
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.304069 -ini_phi 1.794474 -ini_psi 4.463854 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.095288 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.09529
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.26893_ph0.51573_ps3.17304
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.268927 -ini_phi 0.515735 -ini_psi 3.173043 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.732521 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.73252
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.22954_ph3.37372_ps6.01071
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.229540 -ini_phi 3.373725 -ini_psi 6.010706 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.454091 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.45409
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.38736_ph4.50011_ps3.10386
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.387360 -ini_phi 4.500109 -ini_psi 3.103863 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.835656 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.83566
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.74008_ph6.05050_ps0.80551
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.740084 -ini_phi 6.050502 -ini_psi 0.805513 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.397361 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.39736
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.71008_ph1.33259_ps2.18531
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.710080 -ini_phi 1.332586 -ini_psi 2.185305 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.949814 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.94981
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.99823_ph1.82560_ps5.58523
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.998232 -ini_phi 1.825597 -ini_psi 5.585226 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.078775 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.07878
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.51727_ph0.78949_ps3.76333
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.517270 -ini_phi 0.789492 -ini_psi 3.763329 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.166941 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.16694
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.41024_ph0.73613_ps2.75291
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.410243 -ini_phi 0.736132 -ini_psi 2.752915 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.607054 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.60705
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.41044_ph2.74713_ps0.81725
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.410440 -ini_phi 2.747130 -ini_psi 0.817252 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.842998 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.84300
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.68592_ph0.16863_ps0.47557
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.685923 -ini_phi 0.168626 -ini_psi 0.475573 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.519678 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.51968
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.61471_ph5.39663_ps3.93307
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.614711 -ini_phi 5.396626 -ini_psi 3.933067 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.219444 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.21944
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.67535_ph0.76953_ps1.54285
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.675354 -ini_phi 0.769525 -ini_psi 1.542849 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.419121 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.41912
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.47723_ph3.52109_ps3.42385
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.477231 -ini_phi 3.521088 -ini_psi 3.423855 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.543259 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.54326
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.44935_ph3.58338_ps4.07628
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.449351 -ini_phi 3.583377 -ini_psi 4.076280 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.560860 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.56086
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.87643_ph5.98875_ps6.18224
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.876427 -ini_phi 5.988753 -ini_psi 6.182237 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.306857 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.30686
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.72015_ph2.81410_ps0.95683
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.720152 -ini_phi 2.814102 -ini_psi 0.956831 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.035881 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.03588
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.35571_ph2.31555_ps1.66017
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.355706 -ini_phi 2.315547 -ini_psi 1.660174 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.387661 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.38766
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.48138_ph1.81119_ps5.61179
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.481381 -ini_phi 1.811187 -ini_psi 5.611794 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.912873 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.91287
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.38220_ph3.31274_ps5.84603
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.382198 -ini_phi 3.312737 -ini_psi 5.846030 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.962953 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.96295
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.82525_ph3.80549_ps2.98132
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.825252 -ini_phi 3.805486 -ini_psi 2.981316 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.490558 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.49056
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.80487_ph1.32911_ps0.21998
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.804873 -ini_phi 1.329107 -ini_psi 0.219978 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.628226 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.62823
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.54027_ph1.66331_ps4.85133
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.540271 -ini_phi 1.663310 -ini_psi 4.851330 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.557095 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.55709
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.52443_ph3.13724_ps0.33268
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.524426 -ini_phi 3.137243 -ini_psi 0.332684 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.660410 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.66041
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.53693_ph1.97120_ps1.17539
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.536927 -ini_phi 1.971205 -ini_psi 1.175395 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.638570 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.63857
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.78703_ph1.44655_ps3.08467
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.787031 -ini_phi 1.446552 -ini_psi 3.084667 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.621248 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.62125
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.58673_ph0.68895_ps2.14604
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.586727 -ini_phi 0.688950 -ini_psi 2.146036 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.897873 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.89787
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.34462_ph5.78331_ps0.46540
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.344616 -ini_phi 5.783306 -ini_psi 0.465401 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.159059 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.15906
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.08293_ph1.22423_ps1.01967
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.082926 -ini_phi 1.224227 -ini_psi 1.019669 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.587428 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.58743
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.90921_ph1.67257_ps4.58239
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.909207 -ini_phi 1.672573 -ini_psi 4.582392 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.524986 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.52499
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.07200_ph3.50843_ps5.84361
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.071999 -ini_phi 3.508434 -ini_psi 5.843605 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.633496 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.63350
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.20121_ph2.49811_ps5.40026
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.201208 -ini_phi 2.498108 -ini_psi 5.400262 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.584671 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.58467
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.35714_ph2.15186_ps4.03784
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.357139 -ini_phi 2.151860 -ini_psi 4.037842 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.460290 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.46029
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.10096_ph2.09823_ps3.88680
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.100956 -ini_phi 2.098229 -ini_psi 3.886797 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.265532 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.26553
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.21647_ph1.21781_ps2.17835
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.216470 -ini_phi 1.217807 -ini_psi 2.178347 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.952211 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.95221
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.92045_ph1.19092_ps5.83962
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.920454 -ini_phi 1.190915 -ini_psi 5.839620 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.285276 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.28528
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.67106_ph6.20110_ps1.39320
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.671056 -ini_phi 6.201099 -ini_psi 1.393200 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.804894 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.80489
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.84167_ph0.46189_ps1.49238
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.841673 -ini_phi 0.461892 -ini_psi 1.492383 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.455727 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.45573
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.35249_ph5.32190_ps3.87052
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.352492 -ini_phi 5.321901 -ini_psi 3.870519 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.861784 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.86178
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.03575_ph3.51159_ps3.45133
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.035753 -ini_phi 3.511594 -ini_psi 3.451332 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.829435 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.82943
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th1.35264_ph3.69524_ps5.81171
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 1.352642 -ini_phi 3.695242 -ini_psi 5.811706 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.387521 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.38752
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.82722_ph3.20926_ps4.19526
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.827221 -ini_phi 3.209264 -ini_psi 4.195256 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 2.428433 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail02.42843
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.58858_ph2.43205_ps0.16008
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.588582 -ini_phi 2.432053 -ini_psi 0.160084 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 4.196738 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail04.19674
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.09049_ph2.73443_ps2.18454
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.090486 -ini_phi 2.734429 -ini_psi 2.184535 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.022747 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.02275
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.41035_ph4.91834_ps4.93204
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.410349 -ini_phi 4.918337 -ini_psi 4.932041 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.550522 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.55052
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th2.30574_ph4.44269_ps1.87620
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 2.305744 -ini_phi 4.442689 -ini_psi 1.876202 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.825263 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.82526
# make folder /home/zhangji/stokes_flow_master/head_Force/do_calculate_table/ecoC01B05_inithphps_n/th0.10323_ph4.90516_ps3.00096
# input 50 cases.
# generate 1 pbs files in total.
#  --->>random order mode is ON.
# Command of first case is:
# python ../../../do_calculate.py   -ini_theta 0.103233 -ini_phi 4.905164 -ini_psi 3.000956 -max_t 10000.000000 -rtol 1.000000e-09 -atol 1.000000e-12 -eval_dt 1.000000e-03 -calculate_fun do_ShearFlowPetsc4nPsiObj -update_fun 5bs -table_name ecoC01B05_baseFlow_refine -omega_tail 3.554364 -flow_strength 1.000000 -ini_t 0.000000 -f omega_tail03.55436

# %%
np.linspace(2.5, 4.5, 50)
# Out:
# array([2.5       , 2.54081633, 2.58163265, 2.62244898, 2.66326531,
#        2.70408163, 2.74489796, 2.78571429, 2.82653061, 2.86734694,
#        2.90816327, 2.94897959, 2.98979592, 3.03061224, 3.07142857,
#        3.1122449 , 3.15306122, 3.19387755, 3.23469388, 3.2755102 ,
#        3.31632653, 3.35714286, 3.39795918, 3.43877551, 3.47959184,
#        3.52040816, 3.56122449, 3.60204082, 3.64285714, 3.68367347,
#        3.7244898 , 3.76530612, 3.80612245, 3.84693878, 3.8877551 ,
#        3.92857143, 3.96938776, 4.01020408, 4.05102041, 4.09183673,
#        4.13265306, 4.17346939, 4.21428571, 4.25510204, 4.29591837,
#        4.33673469, 4.37755102, 4.41836735, 4.45918367, 4.5       ])
